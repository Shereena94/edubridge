# %% [markdown]
# # LITERACY RATE ANALYSIS

# %% [markdown]
# INTRODUCTION
#
# Literacy Rate:
# Literacy Rate is the number of educated people in a population, over the age of fifteen who can read and write.

# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the file

# %%
lit=pd.read_csv(r"C:\Users\SHEREENA\Downloads\GOI.csv")
lit
# Out:
#            Category Country/ States/ Union Territories Name  \
# 0           Country                                   INDIA
# 1             State                          Andhra Pradesh
# 2             State                       Arunachal Pradesh
# 3             State                                   Assam
# 4             State                                   Bihar
# 5             State                            Chhattisgarh
# 6             State                                     Goa
# 7             State                                 Gujarat
# 8             State                                 Haryana
# 9             State                        Himachal Pradesh
# 10            State                         Jammu & Kashmir
# 11            State                               Jharkhand
# 12            State                               Karnataka
# 13            State                                  Kerala
# 14            State                          Madhya Pradesh
# ...

# %% [markdown]
# # Rename the columns

# %%
lit.rename(columns={'Country/ States/ Union Territories Name':'Place','Literacy Rate (Persons) - Total - 2001':'LR_total_2001','Literacy Rate (Persons) - Total - 2011':'LR_total_2011'},inplace=True)

# %%
lit.rename(columns={'Literacy Rate (Persons) - Rural - 2001':'LR_rural_2001','Literacy Rate (Persons) - Rural - 2011':'LR_rural_2011'},inplace=True)

# %%
lit.rename(columns={'Literacy Rate (Persons) - Urban - 2001':'LR_urban_2001','Literacy Rate (Persons) - Urban - 2011':'LR_urban_2011'},inplace=True)

# %%
lit
# Out:
#            Category              Place  LR_total_2001  LR_total_2011  \
# 0           Country              INDIA           64.8           73.0
# 1             State     Andhra Pradesh           60.5           67.0
# 2             State  Arunachal Pradesh           54.3           65.4
# 3             State              Assam           63.3           72.2
# 4             State              Bihar           47.0           61.8
# 5             State       Chhattisgarh           64.7           70.3
# 6             State                Goa           82.0           88.7
# 7             State            Gujarat           69.1           78.0
# 8             State            Haryana           67.9           75.6
# 9             State   Himachal Pradesh           76.5           82.8
# 10            State    Jammu & Kashmir           55.5           67.2
# 11            State          Jharkhand           53.6           66.4
# 12            State          Karnataka           66.6           75.4
# ...

# %% [markdown]
# # check how many rows and columns

# %%
lit.shape
# Out:
# (36, 8)

# %% [markdown]
# # check datatypes of  attributes

# %%
lit.dtypes
# Out:
# Category          object
# Place             object
# LR_total_2001    float64
# LR_total_2011    float64
# LR_rural_2001    float64
# LR_rural_2011    float64
# LR_urban_2001    float64
# LR_urban_2011    float64
# dtype: object

# %% [markdown]
# # check indexes

# %%
lit.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %% [markdown]
# # check number  of  dimensions

# %%
lit.ndim
# Out:
# 2

# %% [markdown]
# # size of dataset

# %%
lit.size
# Out:
# 288

# %% [markdown]
# # check datatype is empty or not

# %%
lit.empty
# Out:
# False

# %% [markdown]
# # print the column names

# %%
lit.columns
# Out:
# Index(['Category', 'Place', 'LR_total_2001', 'LR_total_2011', 'LR_rural_2001',
#        'LR_rural_2011', 'LR_urban_2001', 'LR_urban_2011'],
#       dtype='object')

# %% [markdown]
# # print top ten rows

# %%
lit.head(10)
# Out:
#   Category              Place  LR_total_2001  LR_total_2011  LR_rural_2001  \
# 0  Country              INDIA           64.8           73.0           58.7
# 1    State     Andhra Pradesh           60.5           67.0           54.5
# 2    State  Arunachal Pradesh           54.3           65.4           47.8
# 3    State              Assam           63.3           72.2           59.7
# 4    State              Bihar           47.0           61.8           43.9
# 5    State       Chhattisgarh           64.7           70.3           60.5
# 6    State                Goa           82.0           88.7           79.7
# 7    State            Gujarat           69.1           78.0           61.3
# 8    State            Haryana           67.9           75.6           63.2
# 9    State   Himachal Pradesh           76.5           82.8           75.1
#
#    LR_rural_2011  LR_urban_2001  LR_urban_2011
# 0           67.8           79.9           84.1
# 1           60.4           76.1           80.1
# ...

# %% [markdown]
# # print bottom 10rows

# %%
lit.tail(10)
# Out:
#            Category          Place  LR_total_2001  LR_total_2011  \
# 26            State  Uttar Pradesh           56.3           67.7
# 27            State    Uttarakhand           71.6           78.8
# 28            State    West Bengal           68.6           76.3
# 29  Union Territory  A & N Islands           81.3           86.6
# 30  Union Territory     Chandigarh           81.9           86.0
# 31  Union Territory   D & N Haveli           57.6           76.2
# 32  Union Territory    Daman & Diu           78.2           87.1
# 33  Union Territory    Lakshadweep           86.7           91.8
# 34  Union Territory   NCT of Delhi           81.7           86.2
# 35  Union Territory     Puducherry           81.2           85.8
#
#     LR_rural_2001  LR_rural_2011  LR_urban_2001  LR_urban_2011
# 26           52.5           65.5           69.8           75.1
# 27           68.1           76.3           81.4           84.5
# ...

# %% [markdown]
# # print the information of dataset

# %%
lit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       36 non-null     object
#  1   Place          36 non-null     object
#  2   LR_total_2001  36 non-null     float64
#  3   LR_total_2011  36 non-null     float64
#  4   LR_rural_2001  36 non-null     float64
#  5   LR_rural_2011  36 non-null     float64
#  6   LR_urban_2001  36 non-null     float64
#  7   LR_urban_2011  36 non-null     float64
# dtypes: float64(6), object(2)
# memory usage: 2.4+ KB

# %% [markdown]
# # print statistical information

# %%
lit.describe()
# Out:
#        LR_total_2001  LR_total_2011  LR_rural_2001  LR_rural_2011  \
# count      36.000000      36.000000      36.000000      36.000000
# mean       69.433333      77.711111      64.669444      73.413889
# std        10.647709       8.497723      11.459440       9.190497
# min        47.000000      61.800000      43.900000      59.800000
# 25%        62.975000      71.725000      57.425000      65.875000
# 50%        68.700000      76.600000      63.300000      71.900000
# 75%        77.225000      85.850000      74.275000      80.875000
# max        90.900000      94.000000      90.000000      93.000000
#
#        LR_urban_2001  LR_urban_2011
# count      36.000000      36.000000
# mean       82.161111      86.283333
# std         5.463138       4.982856
# min        69.800000      75.100000
# 25%        79.275000      83.175000
# 50%        81.850000      86.250000
# 75%        84.925000      89.650000
# max        96.100000      97.600000

# %% [markdown]
# # To check is there any missing values

# %%
lit.isna()
# Out:
#     Category  Place  LR_total_2001  LR_total_2011  LR_rural_2001  \
# 0      False  False          False          False          False
# 1      False  False          False          False          False
# 2      False  False          False          False          False
# 3      False  False          False          False          False
# 4      False  False          False          False          False
# 5      False  False          False          False          False
# 6      False  False          False          False          False
# 7      False  False          False          False          False
# 8      False  False          False          False          False
# 9      False  False          False          False          False
# 10     False  False          False          False          False
# 11     False  False          False          False          False
# 12     False  False          False          False          False
# ...

# %% [markdown]
# # sum of missing values

# %%
lit.isna().sum()
# Out:
# Category         0
# Place            0
# LR_total_2001    0
# LR_total_2011    0
# LR_rural_2001    0
# LR_rural_2011    0
# LR_urban_2001    0
# LR_urban_2011    0
# dtype: int64

# %% [markdown]
# # check the duplicate value

# %%
lit.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %% [markdown]
# # sum of duplicate values

# %%
lit.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # number of unique values in dataset

# %%
lit.nunique()
# Out:
# Category          3
# Place            36
# LR_total_2001    35
# LR_total_2011    36
# LR_rural_2001    36
# LR_rural_2011    34
# LR_urban_2001    32
# LR_urban_2011    33
# dtype: int64

# %% [markdown]
# # print unique in dataset

# %%
lit['Category'].unique()
# Out:
# array(['Country', 'State', 'Union Territory'], dtype=object)

# %% [markdown]
# # print the count of category in the dataset

# %%
lit.Category.value_counts()
# Out:
# State              28
# Union Territory     7
# Country             1
# Name: Category, dtype: int64

# %% [markdown]
# # to show the literacy rate in rural places(2011) >80

# %%
lit
# Out:
#            Category              Place  LR_total_2001  LR_total_2011  \
# 0           Country              INDIA           64.8           73.0
# 1             State     Andhra Pradesh           60.5           67.0
# 2             State  Arunachal Pradesh           54.3           65.4
# 3             State              Assam           63.3           72.2
# 4             State              Bihar           47.0           61.8
# 5             State       Chhattisgarh           64.7           70.3
# 6             State                Goa           82.0           88.7
# 7             State            Gujarat           69.1           78.0
# 8             State            Haryana           67.9           75.6
# 9             State   Himachal Pradesh           76.5           82.8
# 10            State    Jammu & Kashmir           55.5           67.2
# 11            State          Jharkhand           53.6           66.4
# 12            State          Karnataka           66.6           75.4
# ...

# %%
rural=lit[['Category','Place','LR_rural_2011']]
rural
# Out:
#            Category              Place  LR_rural_2011
# 0           Country              INDIA           67.8
# 1             State     Andhra Pradesh           60.4
# 2             State  Arunachal Pradesh           59.9
# 3             State              Assam           69.3
# 4             State              Bihar           59.8
# 5             State       Chhattisgarh           66.0
# 6             State                Goa           86.6
# 7             State            Gujarat           71.7
# 8             State            Haryana           71.4
# 9             State   Himachal Pradesh           81.9
# 10            State    Jammu & Kashmir           63.2
# 11            State          Jharkhand           61.1
# 12            State          Karnataka           68.7
# 13            State             Kerala           93.0
# 14            State     Madhya Pradesh           63.9
# 15            State        Maharashtra           77.0
# ...

# %%
rural.sort_values('LR_rural_2011').tail(10)
# Out:
#            Category             Place  LR_rural_2011
# 30  Union Territory        Chandigarh           80.7
# 32  Union Territory       Daman & Diu           81.4
# 34  Union Territory      NCT of Delhi           81.9
# 9             State  Himachal Pradesh           81.9
# 18            State           Mizoram           84.1
# 29  Union Territory     A & N Islands           84.5
# 25            State           Tripura           84.9
# 6             State               Goa           86.6
# 33  Union Territory       Lakshadweep           91.6
# 13            State            Kerala           93.0

# %% [markdown]
# # to show the literacy rate in urban areas (2011) >90

# %%
urban=lit[['Category','Place','LR_urban_2011']]
urban
# Out:
#            Category              Place  LR_urban_2011
# 0           Country              INDIA           84.1
# 1             State     Andhra Pradesh           80.1
# 2             State  Arunachal Pradesh           82.9
# 3             State              Assam           88.5
# 4             State              Bihar           76.9
# 5             State       Chhattisgarh           84.0
# 6             State                Goa           90.0
# 7             State            Gujarat           86.3
# 8             State            Haryana           83.1
# 9             State   Himachal Pradesh           91.1
# 10            State    Jammu & Kashmir           77.1
# 11            State          Jharkhand           82.3
# 12            State          Karnataka           85.8
# 13            State             Kerala           95.1
# 14            State     Madhya Pradesh           82.8
# 15            State        Maharashtra           88.7
# ...

# %%
u=urban.loc[(urban["LR_urban_2011"]>=90)]
u
# Out:
#            Category             Place  LR_urban_2011
# 6             State               Goa           90.0
# 9             State  Himachal Pradesh           91.1
# 13            State            Kerala           95.1
# 17            State         Meghalaya           90.8
# 18            State           Mizoram           97.6
# 25            State           Tripura           93.5
# 29  Union Territory     A & N Islands           90.1
# 33  Union Territory       Lakshadweep           91.9

# %% [markdown]
# These are the places where the literacy rate is greater than 90%.in case of Urban areas ,mizoram has the top most literacy rate.

# %% [markdown]
# # grouping total literacy rate in 2001 by category wise

# %%
lrt=lit.groupby(['Category']).agg({'LR_total_2001':'sum'})
lrt
# Out:
#                  LR_total_2001
# Category
# Country                   64.8
# State                   1886.2
# Union Territory          548.6

# %% [markdown]
# #  grouping total literacy rate in 2011 by category wise

# %%
lit.groupby(['Category']).agg({'LR_total_2011':'sum'})
# Out:
#                  LR_total_2011
# Category
# Country                   73.0
# State                   2124.9
# Union Territory          599.7

# %% [markdown]
# # show the maximum rates

# %%
lit.max()
# Out:
# Category         Union Territory
# Place                West Bengal
# LR_total_2001               90.9
# LR_total_2011               94.0
# LR_rural_2001               90.0
# LR_rural_2011               93.0
# LR_urban_2001               96.1
# LR_urban_2011               97.6
# dtype: object

# %% [markdown]
# # show the minimum rates

# %%
lit.min()
# Out:
# Category               Country
# Place            A & N Islands
# LR_total_2001             47.0
# LR_total_2011             61.8
# LR_rural_2001             43.9
# LR_rural_2011             59.8
# LR_urban_2001             69.8
# LR_urban_2011             75.1
# dtype: object

# %% [markdown]
# # correlation

# %%
lit.corr()
# Out:
#                LR_total_2001  LR_total_2011  LR_rural_2001  LR_rural_2011  \
# LR_total_2001       1.000000       0.952126       0.985199       0.934016
# LR_total_2011       0.952126       1.000000       0.944638       0.971140
# LR_rural_2001       0.985199       0.944638       1.000000       0.960003
# LR_rural_2011       0.934016       0.971140       0.960003       1.000000
# LR_urban_2001       0.760652       0.814676       0.736025       0.770266
# LR_urban_2011       0.749828       0.839234       0.729318       0.784652
#
#                LR_urban_2001  LR_urban_2011
# LR_total_2001       0.760652       0.749828
# LR_total_2011       0.814676       0.839234
# LR_rural_2001       0.736025       0.729318
# LR_rural_2011       0.770266       0.784652
# LR_urban_2001       1.000000       0.981313
# LR_urban_2011       0.981313       1.000000

# %% [markdown]
# # query to extract state wise data

# %%
lit_state=lit.loc[(lit['Category']=='State')]
lit_state
# Out:
#    Category              Place  LR_total_2001  LR_total_2011  LR_rural_2001  \
# 1     State     Andhra Pradesh           60.5           67.0           54.5
# 2     State  Arunachal Pradesh           54.3           65.4           47.8
# 3     State              Assam           63.3           72.2           59.7
# 4     State              Bihar           47.0           61.8           43.9
# 5     State       Chhattisgarh           64.7           70.3           60.5
# 6     State                Goa           82.0           88.7           79.7
# 7     State            Gujarat           69.1           78.0           61.3
# 8     State            Haryana           67.9           75.6           63.2
# 9     State   Himachal Pradesh           76.5           82.8           75.1
# 10    State    Jammu & Kashmir           55.5           67.2           49.8
# 11    State          Jharkhand           53.6           66.4           45.7
# ...

# %% [markdown]
# # query to extract the data of union territory

# %%
lit_union=lit.loc[(lit['Category']=='Union Territory')]
lit_union
# Out:
#            Category          Place  LR_total_2001  LR_total_2011  \
# 29  Union Territory  A & N Islands           81.3           86.6
# 30  Union Territory     Chandigarh           81.9           86.0
# 31  Union Territory   D & N Haveli           57.6           76.2
# 32  Union Territory    Daman & Diu           78.2           87.1
# 33  Union Territory    Lakshadweep           86.7           91.8
# 34  Union Territory   NCT of Delhi           81.7           86.2
# 35  Union Territory     Puducherry           81.2           85.8
#
#     LR_rural_2001  LR_rural_2011  LR_urban_2001  LR_urban_2011
# 29           78.7           84.5           86.6           90.1
# 30           75.6           80.7           82.6           86.2
# 31           49.3           64.1           84.4           89.8
# 32           75.8           81.4           82.3           89.0
# 33           85.0           91.6           88.6           91.9
# 34           78.1           81.9           81.9           86.3
# ...

# %% [markdown]
# # Higher literacy rate across union territory-2011

# %%
union_2011=lit_union[['Place','LR_total_2011','LR_rural_2011','LR_urban_2011']]
union_2011
# Out:
#             Place  LR_total_2011  LR_rural_2011  LR_urban_2011
# 29  A & N Islands           86.6           84.5           90.1
# 30     Chandigarh           86.0           80.7           86.2
# 31   D & N Haveli           76.2           64.1           89.8
# 32    Daman & Diu           87.1           81.4           89.0
# 33    Lakshadweep           91.8           91.6           91.9
# 34   NCT of Delhi           86.2           81.9           86.3
# 35     Puducherry           85.8           80.1           88.5

# %% [markdown]
# Among the Union territories Lakshadweep	has the highest rate in literacy.

# %% [markdown]
# # DATA VISUALISATION

# %% [markdown]
# # Literacy Rate across states

# %%
plt.bar(lit_state['Place'],lit_state['LR_total_2011'])
plt.title('State Vs Literacy_2011',fontsize=15,color='green')
plt.xlabel('States',fontsize=15)
plt.ylabel('Literacy rate_2011',fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# # Literacy Rate across union Territory-2011

# %%
union_2011.plot(kind='bar',figsize=(60,30))
plt.tick_params(axis='y',labelsize=33)
plt.tick_params(axis='x',labelsize=33)
plt.xlabel("Place",fontsize=40)
plt.ylabel("Literacy Rate",fontsize=40)
plt.title("Literacy Rate across union Territory-2011",fontsize=55)
plt.legend(["LR_total_2011","LR_rural_2011","LR_urban_2011"],prop={"size":30})
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Line plot

# %%
sns.lineplot(x="LR_total_2011",y="LR_total_2001",hue="Category",data=lit)
plt.show()

# %% [markdown]
# # Pie chart

# %%
plt.title("Literacy Rate in urban areas",fontsize=20)
urban['Category'].value_counts().plot.pie(autopct="%1.1f%%",shadow=True)
plt.show()

# %%
lrt
# Out:
#                  LR_total_2001
# Category
# Country                   64.8
# State                   1886.2
# Union Territory          548.6

# %%
plt.title("Total Literacy rate in 2001 by category wise",fontsize=20)
lrt['LR_total_2001'].value_counts().plot.pie(autopct="%1.1f%%",shadow=True)
plt.show()

# %% [markdown]
# # Total literacy rate of Union Terrotories in 2001 and 2011

# %%
lit_union.groupby('Place')[['LR_total_2001','LR_total_2011',]].sum().plot.bar(color=['green','orange'],
                                                                                          figsize=(10,5))
plt.title("Literacy Rate of Union Terrotories",fontsize=20,color="red")
plt.ylabel('Rate')
plt.show()

# %% [markdown]
# The above graph shows the literacy rate of Union Territories.From this, we can realize that Lekshadweep has the highest rate in literacy from 2001 to 2011.

# %% [markdown]
# # Literacy rate of rural places in the year 2001 and 2011

# %%
lit.groupby('Place')[['LR_rural_2001','LR_rural_2011',]].sum().plot.bar(color=
                                                                  ['green','magenta'],figsize=(15,5))
plt.title("Literacy Rate of Rural areas",fontsize=20,color="blue")
plt.ylabel('Rate')
plt.show()

# %% [markdown]
# The above graph shows literacy rate of rural areas.Kerala has the highest literacy rate from 2001 to 2011.

# %% [markdown]
# # Literacy rate in rural and urban areas

# %%
lit_state.groupby('Place')[['LR_rural_2001','LR_rural_2011','LR_urban_2001','LR_urban_2011']].sum().plot.bar(color
                                                                    =['red','green','yellow','cyan'],figsize=(20,5))
plt.title("Literacy rate in rural and urban areas",color="Green",fontsize=25)
plt.ylabel('Rate')
# Out:
# Text(0, 0.5, 'Rate')

# %% [markdown]
# The above graph shows literacy rate is increases linearly from 2001 to 2011.in case of each place it shows higher rate in the year 2011.

# %% [markdown]
# # strip plot

# %%
sns.set_style("darkgrid")
sns.stripplot(x="Place",y="LR_total_2001",hue="LR_total_2011",data=lit_state)
plt.show()

# %% [markdown]
# # Total literacy rate  in 2001(kde plot)

# %%
sns.kdeplot(lit['Literacy Rate (Persons) - Total - 2001'])
plt.show()

# %% [markdown]
# # Literacy rate in rural places - 2001 and 2011

# %%
sns.kdeplot(lit['Literacy Rate (Persons) - Rural - 2001'],lit['Literacy Rate (Persons) - Rural - 2011'],color='orange',shade=True)
plt.show()

# %% [markdown]
# # Literacy rate Rural vs Urban in 2011

# %% [markdown]
# # pairplot

# %%
sns.pairplot(lit[lit.Category.isin(['Country','State','Union Territory'])],
            hue='Category',
            vars=['LR_total_2011','LR_rural_2011','LR_urban_2011'],
            palette='inferno_r')
plt.show()

# %%
sns.pairplot(lit)
plt.show()

# %%
sns.pairplot(lit,diag_kind='kde',hue='Category')
plt.show()

# %%
sns.pairplot(lit,diag_kind='hist',kind='reg')
plt.show()

# %% [markdown]
# # heat map

# %%
sns.heatmap(lit.corr())
plt.show()

# %%
sns.heatmap(lit.corr(), cmap='RdBu',annot=True)
plt.show()

# %%
sns.distplot(lit_union.LR_total_2001)
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ### As per the results of 2011 census reveal that there has been an increase in literacy in the country. The literacy rate in the country is 74.04 per cent, 82.14 for males and 65.46 for females. Kerala retained its position by being on top with a 93.91 per cent literacy rate, closely followed by Lakshadweep (92.28 per cent) and Mizoram (91.58 per cent).Literacy in India is a key for socio-economic progress. Despite government programmes, India's literacy rate increased only "sluggishly". The 2011 census, indicated a 2001–2011 decadal literacy growth of 9.2%, which is slower than the growth seen during the previous decade. An old analytical 1990 study estimated that it would take until 2060 for India to achieve universal literacy at then-current rate of progress.

# %% [markdown]
# # THANKYOU
