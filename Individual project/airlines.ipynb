# %% [markdown]
# # Airlines analysis

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the File

# %%
air=pd.read_csv(r"C:\Users\SHEREENA\Downloads\airlines.csv")
air
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#       Unnamed: 2  Unnamed: 3 Time.Month Name  Time.Year  \
# 0            NaN         NaN            June       2003
# ...

# %% [markdown]
# # Check how many rows and columns

# %%
air.shape
# Out:
# (4408, 24)

# %% [markdown]
# # Check Datatypes of attributes

# %%
air.dtypes
# Out:
# Airport.Code                                            object
# Airport.Name                                            object
# Unnamed: 2                                             float64
# Unnamed: 3                                             float64
# Time.Month Name                                         object
# Time.Year                                                int64
# Statistics.# of Delays.Carrier                           int64
# Statistics.# of Delays.Late Aircraft                     int64
# Statistics.# of Delays.National Aviation System          int64
# Statistics.# of Delays.Security                          int64
# Statistics.# of Delays.Weather                           int64
# Statistics.Carriers.Names                               object
# Statistics.Carriers.Total                                int64
# Statistics.Flights.Cancelled                             int64
# Statistics.Flights.Delayed                               int64
# ...

# %% [markdown]
# # check indexes

# %%
air.index
# Out:
# RangeIndex(start=0, stop=4408, step=1)

# %% [markdown]
# # check datatype is empty or not

# %%
air.empty
# Out:
# False

# %% [markdown]
# # To check is there any missing value

# %%
air.isna()
# Out:
#       Airport.Code  Airport.Name  Unnamed: 2  Unnamed: 3  Time.Month Name  \
# 0            False         False        True        True            False
# 1            False         False        True        True            False
# 2            False         False        True        True            False
# 3            False         False        True        True            False
# 4            False         False        True        True            False
# ...            ...           ...         ...         ...              ...
# 4403         False         False        True        True            False
# 4404         False         False        True        True            False
# 4405         False         False        True        True            False
# 4406         False         False        True        True            False
# 4407         False         False        True        True            False
#
#       Time.Year  Statistics.# of Delays.Carrier  \
# ...

# %%
air.isnull()
# Out:
#       Airport.Code  Airport.Name  Unnamed: 2  Unnamed: 3  Time.Month Name  \
# 0            False         False        True        True            False
# 1            False         False        True        True            False
# 2            False         False        True        True            False
# 3            False         False        True        True            False
# 4            False         False        True        True            False
# ...            ...           ...         ...         ...              ...
# 4403         False         False        True        True            False
# 4404         False         False        True        True            False
# 4405         False         False        True        True            False
# 4406         False         False        True        True            False
# 4407         False         False        True        True            False
#
#       Time.Year  Statistics.# of Delays.Carrier  \
# ...

# %% [markdown]
# # sum of missing value

# %%
air.isna().sum()
# Out:
# Airport.Code                                              0
# Airport.Name                                              0
# Unnamed: 2                                             4408
# Unnamed: 3                                             4408
# Time.Month Name                                           0
# Time.Year                                                 0
# Statistics.# of Delays.Carrier                            0
# Statistics.# of Delays.Late Aircraft                      0
# Statistics.# of Delays.National Aviation System           0
# Statistics.# of Delays.Security                           0
# Statistics.# of Delays.Weather                            0
# Statistics.Carriers.Names                                 0
# Statistics.Carriers.Total                                 0
# Statistics.Flights.Cancelled                              0
# Statistics.Flights.Delayed                                0
# Statistics.Flights.Diverted                               0
# ...

# %% [markdown]
# # check number of dimensions

# %%
air.ndim
# Out:
# 2

# %% [markdown]
# # size of dataset

# %%
air.size
# Out:
# 105792

# %% [markdown]
# # print the column names

# %%
air.columns
# Out:
# Index(['Airport.Code', 'Airport.Name', 'Unnamed: 2', 'Unnamed: 3',
#        'Time.Month Name', 'Time.Year', 'Statistics.# of Delays.Carrier',
#        'Statistics.# of Delays.Late Aircraft',
#        'Statistics.# of Delays.National Aviation System',
#        'Statistics.# of Delays.Security', 'Statistics.# of Delays.Weather',
#        'Statistics.Carriers.Names', 'Statistics.Carriers.Total',
#        'Statistics.Flights.Cancelled', 'Statistics.Flights.Delayed',
#        'Statistics.Flights.Diverted', 'Statistics.Flights.On Time',
#        'Statistics.Flights.Total', 'Statistics.Minutes Delayed.Carrier',
#        'Statistics.Minutes Delayed.Late Aircraft',
#        'Statistics.Minutes Delayed.National Aviation System',
#        'Statistics.Minutes Delayed.Security',
#        'Statistics.Minutes Delayed.Weather',
#        'Statistics.Minutes Delayed.Total'],
#       dtype='object')

# %% [markdown]
# # Rename the columns

# %%
air.rename(columns={'Time.Month Name':'Month','Time.Year':'Year','Statistics.# of Delays.Carrier':'Delays.Carrier'},inplace=True)

# %%
air.rename(columns={'Statistics.# of Delays.Late Aircraft':'Delays.Late Aircraft','Statistics.# of Delays.National Aviation System':'Delays.National Aviation System'},inplace=True)

# %%
air.rename(columns={'Statistics.# of Delays.Security':'Delays.Security','Statistics.# of Delays.Weather':'Delays.Weather','Statistics.Carriers.Names':'Carriers.Names'},inplace=True)

# %%
air.rename(columns={'Statistics.Carriers.Total':'Carriers.Total','Statistics.Flights.Cancelled':'Flights.Cancelled','Statistics.Flights.Delayed':'Flights.Delayed'},inplace=True)

# %%
air.rename(columns={'Statistics.Flights.Diverted':'Flights.Diverted','Statistics.Flights.On Time':'Flights.On Time','Statistics.Flights.Total':'Flights.Total','Statistics.Minutes Delayed.Carrier':'Minutes Delayed.Carrier'},inplace=True)

# %%
air.rename(columns={'Statistics.Minutes Delayed.Late Aircraft':'Minutes Delayed.Late Aircraft','Statistics.Minutes Delayed.National Aviation System':'Minutes Delayed.National Aviation System'},inplace=True)

# %%
air.rename(columns={'Statistics.Minutes Delayed.Security':'Minutes Delayed.Security','Statistics.Minutes Delayed.Weather':'Minutes Delayed.Weather','Statistics.Minutes Delayed.Total':'Minutes Delayed.Total'},inplace=True)

# %%
air
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#       Unnamed: 2  Unnamed: 3    Month  Year  Delays.Carrier  \
# 0            NaN         NaN     June  2003            1009
# ...

# %% [markdown]
# # Print top 25 rows

# %%
air.head(25)
# Out:
#    Airport.Code                                       Airport.Name  \
# 0           ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1           BOS                    Boston, MA: Logan International
# 2           BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3           CLT     Charlotte, NC: Charlotte Douglas International
# 4           DCA  Washington, DC: Ronald Reagan Washington National
# 5           DEN                   Denver, CO: Denver International
# 6           DFW  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...
# 7           DTW            Detroit, MI: Detroit Metro Wayne County
# 8           EWR           Newark, NJ: Newark Liberty International
# 9           FLL  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...
# 10          IAD    Washington, DC: Washington Dulles International
# 11          IAH  Houston, TX: George Bush Intercontinental/Houston
# 12          JFK        New York, NY: John F. Kennedy International
# ...

# %% [markdown]
# # Print bottom 25 rows

# %%
air.tail(25)
# Out:
#      Airport.Code                                       Airport.Name  \
# 4383          DCA  Washington, DC: Ronald Reagan Washington National
# 4384          DEN                   Denver, CO: Denver International
# 4385          DFW  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...
# 4386          DTW            Detroit, MI: Detroit Metro Wayne County
# 4387          EWR           Newark, NJ: Newark Liberty International
# 4388          FLL  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...
# 4389          IAD    Washington, DC: Washington Dulles International
# 4390          IAH  Houston, TX: George Bush Intercontinental/Houston
# 4391          JFK        New York, NY: John F. Kennedy International
# 4392          LAS              Las Vegas, NV: McCarran International
# 4393          LAX         Los Angeles, CA: Los Angeles International
# 4394          LGA                            New York, NY: LaGuardia
# 4395          MCO                 Orlando, FL: Orlando International
# ...

# %% [markdown]
# # check the duplicate value

# %%
air.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4403    False
# 4404    False
# 4405    False
# 4406    False
# 4407    False
# Length: 4408, dtype: bool

# %% [markdown]
# # sum of duplicate values

# %%
air.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # number of unique values in dataset

# %%
air.nunique()
# Out:
# Airport.Code                                  29
# Airport.Name                                  29
# Unnamed: 2                                     0
# Unnamed: 3                                     0
# Month                                         12
# Year                                          14
# Delays.Carrier                              1126
# Delays.Late Aircraft                        1531
# Delays.National Aviation System             1817
# Delays.Security                               51
# Delays.Weather                               346
# Carriers.Names                               841
# Carriers.Total                                16
# Flights.Cancelled                            800
# Flights.Delayed                             2695
# Flights.Diverted                             203
# Flights.On Time                             3672
# Flights.Total                               3840
# Minutes Delayed.Carrier                     4213
# ...

# %% [markdown]
# # Print unique Carriers.Names

# %%
air['Carriers.Names'].unique()
# Out:
# array(['American Airlines Inc.,JetBlue Airways,Continental Air Lines Inc.,Delta Air Lines Inc.,Atlantic Southeast Airlines,AirTran Airways Corporation,America West Airlines Inc.,Northwest Airlines Inc.,ExpressJet Airlines Inc.,United Air Lines Inc.,US Airways Inc.',
#        'American Airlines Inc.,Alaska Airlines Inc.,Continental Air Lines Inc.,Atlantic Coast Airlines,Delta Air Lines Inc.,Atlantic Southeast Airlines,AirTran Airways Corporation,America West Airlines Inc.,American Eagle Airlines Inc.,Northwest Airlines Inc.,ExpressJet Airlines Inc.,ATA Airlines d/b/a ATA,United Air Lines Inc.,US Airways Inc.',
#        'American Airlines Inc.,Continental Air Lines Inc.,Delta Air Lines Inc.,AirTran Airways Corporation,America West Airlines Inc.,American Eagle Airlines Inc.,Northwest Airlines Inc.,ExpressJet Airlines Inc.,United Air Lines Inc.,US Airways Inc.,Southwest Airlines Co.',
# ...

# %% [markdown]
# # count of Carriers.Names

# %%
air['Carriers.Names'].value_counts()
# Out:
# American Airlines Inc.,Alaska Airlines Inc.,JetBlue Airways,Delta Air Lines Inc.,Frontier Airlines Inc.,Hawaiian Airlines Inc.,SkyWest Airlines Inc.,United Air Lines Inc.,US Airways Inc.,Virgin America,Southwest Airlines Co.                                                                                                                                                  76
# American Airlines Inc.,Alaska Airlines Inc.,JetBlue Airways,Delta Air Lines Inc.,Frontier Airlines Inc.,AirTran Airways Corporation,Hawaiian Airlines Inc.,SkyWest Airlines Inc.,United Air Lines Inc.,US Airways Inc.,Virgin America,Southwest Airlines Co.                                                                                                                      65
# ...

# %% [markdown]
# # Grouping the flight names by month wise

# %%
air.groupby(['Month']).agg({'Carriers.Names':'sum'})
# Out:
#                                               Carriers.Names
# Month
# April      American Airlines Inc.,Continental Air Lines I...
# August     American Airlines Inc.,JetBlue Airways,Contine...
# December   American Airlines Inc.,JetBlue Airways,Contine...
# Febuary    American Airlines Inc.,Continental Air Lines I...
# January    American Airlines Inc.,Continental Air Lines I...
# July       American Airlines Inc.,JetBlue Airways,Contine...
# June       American Airlines Inc.,JetBlue Airways,Contine...
# March      American Airlines Inc.,Continental Air Lines I...
# May        American Airlines Inc.,Continental Air Lines I...
# November   American Airlines Inc.,JetBlue Airways,Contine...
# October    American Airlines Inc.,JetBlue Airways,Contine...
# September  American Airlines Inc.,JetBlue Airways,Contine...

# %% [markdown]
# # Grouping delayed flights by month wise

# %%
d1=air.groupby(['Month']).agg({'Delays.Carrier':'sum','Delays.Late Aircraft':'sum','Delays.National Aviation System':'sum','Delays.Security':'sum','Delays.Weather':'sum'})
d1
# Out:
#            Delays.Carrier  Delays.Late Aircraft  \
# Month
# April              181262                251618
# August             238472                328113
# December           269940                372149
# Febuary            185021                258725
# January            220558                289305
# July               265161                381057
# June               256751                372132
# March              209490                292867
# May                187871                264997
# November           172366                222966
# October            182416                242683
# September          163672                201648
#
#            Delays.National Aviation System  Delays.Security  Delays.Weather
# Month
# April                               312505             1592           20177
# August                              358986             3258           34528
# December                            418797             3336           37612
# ...

# %%
sns.pairplot(d1)
plt.show()

# %% [markdown]
# # Month VS Delays.Carrier

# %%
plt.figure(figsize=(17,5))
plt.bar(air['Month'],air['Delays.Carrier'],color='r')
plt.title('Month VS Delays.Carrier',fontsize=15,color='green')
plt.xlabel('Month',fontsize=20,color='black')
plt.xticks(rotation=90)
plt.ylabel("Delays.Carrier",fontsize=20,color='black')
plt.grid(True)
plt.show()

# %% [markdown]
# # Weather delays across various months

# %%
plt.figure(figsize=(17,5))
plt.bar(air['Month'],air['Delays.Weather'],color='magenta')
plt.title('Month VS Delays.Weather',fontsize=25,color='orange')
plt.xlabel('Month',fontsize=20,color='black')
plt.xticks(rotation=90)
plt.ylabel("Delays.Weather",fontsize=20,color='black')

plt.show()

# %% [markdown]
# # National Aviation System Delays across various months

# %%
plt.figure(figsize=(15,3))
sns.lineplot(x='Month',y='Delays.National Aviation System',data=d1,marker="s",color="red")
plt.xticks(rotation=80)

plt.title('National Aviation System Delays across various months')
plt.show()

# %% [markdown]
# # Mean of d1

# %%
d1.mean()
# Out:
# Delays.Carrier                     211081.666667
# Delays.Late Aircraft               289855.000000
# Delays.National Aviation System    350649.166667
# Delays.Security                      2048.083333
# Delays.Weather                      28731.666667
# dtype: float64

# %% [markdown]
# # Mean plot of d1

# %%
plt.figure(figsize=(12,8))
plt.bar(["Delays.Carrier","Delays.Late Aircraft","Delays.National Aviation System","Delays.Security","Delays.Weather"],[211081.666667,289855.000000,350649.166667,2048.083333,28731.666667],label="Mean",color='c',width=0.5)

plt.legend()
plt.xlabel('Delays')
plt.ylabel('mean values')
plt.title('Mean plot of Delay details')
plt.show()

# %% [markdown]
# # Grouping flight details by month wise

# %%
f1=air.groupby(['Month']).agg({'Flights.Cancelled':'sum','Flights.Delayed':'sum','Flights.Diverted':'sum','Flights.On Time':'sum','Flights.Total':'sum'})
f1
# Out:
#            Flights.Cancelled  Flights.Delayed  Flights.Diverted  \
# Month
# April                  55172           767134              8599
# August                 74052           963240             14262
# December              108026          1101829              9349
# Febuary               125630           801497              6945
# January               128455           908789              8400
# July                   79194          1084630             16660
# June                   78791          1085637             16833
# March                  77751           874674              8171
# May                    53908           817071             11524
# November               44491           730990              6886
# October                56295           783858              7281
# September              59599           668669              7989
#
#            Flights.On Time  Flights.Total
# Month
# April              3297188        4128093
# ...

# %% [markdown]
# # Mean of f1

# %%
f1.mean()
# Out:
# Flights.Cancelled    7.844700e+04
# Flights.Delayed      8.823348e+05
# Flights.Diverted     1.024158e+04
# Flights.On Time      3.399457e+06
# Flights.Total        4.370481e+06
# dtype: float64

# %% [markdown]
# # Grouping delayed flights by year wise

# %%
d2=air.groupby(['Year']).agg({'Delays.Carrier':'sum','Delays.Late Aircraft':'sum','Delays.National Aviation System':'sum','Delays.Security':'sum','Delays.Weather':'sum'})
d2
# Out:
#       Delays.Carrier  Delays.Late Aircraft  Delays.National Aviation System  \
# Year
# 2003           87163                104421                           203062
# 2004          188860                242625                           410657
# 2005          218705                269560                           402032
# 2006          244002                323979                           417756
# 2007          273234                369520                           444187
# 2008          217264                306661                           408170
# 2009          174185                247225                           339737
# 2010          178490                253551                           277309
# 2011          173633                255142                           266026
# 2012          172162                241010                           225322
# 2013          195255                304028                           282015
# ...

# %% [markdown]
# # Mean of d2

# %%
d2.mean()
# Out:
# Delays.Carrier                     180927.142857
# Delays.Late Aircraft               248447.142857
# Delays.National Aviation System    300556.428571
# Delays.Security                      1755.500000
# Delays.Weather                      24627.142857
# dtype: float64

# %% [markdown]
# # Grouping flight details by year wise

# %%
f2=air.groupby(['Year']).agg({'Flights.Cancelled':'sum','Flights.Delayed':'sum','Flights.Diverted':'sum','Flights.On Time':'sum','Flights.Total':'sum'})
f2
# Out:
#       Flights.Cancelled  Flights.Delayed  Flights.Diverted  Flights.On Time  \
# Year
# 2003              34598           411570              4791          1922147
# 2004              77940           880677              8731          3377387
# 2005              83188           925578              8978          3355778
# 2006              78475          1024612             11058          3323807
# 2007             102665          1129439             11510          3294874
# 2008              87650           965136             11245          3243618
# 2009              58341           787472              9780          3183307
# 2010              75018           732445              9783          3233526
# 2011              77467           715560              9364          3120904
# 2012              53494           658326              7941          3235628
# 2013              62054           805063              9454          3231826
# ...

# %% [markdown]
# # Mean of f2

# %%
f2.mean()
# Out:
# Flights.Cancelled    6.724029e+04
# Flights.Delayed      7.562870e+05
# Flights.Diverted     8.778500e+03
# Flights.On Time      2.913820e+06
# Flights.Total        3.746126e+06
# dtype: float64

# %% [markdown]
# # Maximum values

# %%
d1.max()
# Out:
# Delays.Carrier                     269940
# Delays.Late Aircraft               381057
# Delays.National Aviation System    418797
# Delays.Security                      3336
# Delays.Weather                      41251
# dtype: int64

# %%
f1.max()
# Out:
# Flights.Cancelled     128455
# Flights.Delayed      1101829
# Flights.Diverted       16833
# Flights.On Time      3676604
# Flights.Total        4754762
# dtype: int64

# %%
d2.max()
# Out:
# Delays.Carrier                     273234
# Delays.Late Aircraft               369520
# Delays.National Aviation System    444187
# Delays.Security                      3555
# Delays.Weather                      39531
# dtype: int64

# %%
f2.max()
# Out:
# Flights.Cancelled     102665
# Flights.Delayed      1129439
# Flights.Diverted       11510
# Flights.On Time      3377387
# Flights.Total        4538488
# dtype: int64

# %% [markdown]
# # minimum values

# %%
d1.min()
# Out:
# Delays.Carrier                     163672
# Delays.Late Aircraft               201648
# Delays.National Aviation System    282856
# Delays.Security                      1371
# Delays.Weather                      18416
# dtype: int64

# %%
f1.min()
# Out:
# Flights.Cancelled      44491
# Flights.Delayed       668669
# Flights.Diverted        6886
# Flights.On Time      2827502
# Flights.Total        3761574
# dtype: int64

# %%
d2.min()
# Out:
# Delays.Carrier                     14009
# Delays.Late Aircraft               16243
# Delays.National Aviation System    16170
# Delays.Security                       97
# Delays.Weather                      1500
# dtype: int64

# %%
f2.min()
# Out:
# Flights.Cancelled      8796
# Flights.Delayed       48026
# Flights.Diverted        449
# Flights.On Time      241363
# Flights.Total        298634
# dtype: int64

# %% [markdown]
# # On time flights across various years

# %%
plt.figure(figsize=(15,3))
sns.lineplot(x='Year',y='Flights.On Time',data=f2,marker="s",color="violet")
plt.xticks(rotation=80)

plt.title('On time flights')
plt.show()

# %% [markdown]
# # print statistical information

# %%
air.describe().all
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of        Unnamed: 2  Unnamed: 3         Year  Delays.Carrier  \
# count         0.0         0.0  4408.000000     4408.000000
# mean          NaN         NaN  2009.243421      574.632486
# std           NaN         NaN     3.667475      329.616475
# min           NaN         NaN  2003.000000      112.000000
# 25%           NaN         NaN  2006.000000      358.000000
# 50%           NaN         NaN  2009.000000      476.000000
# 75%           NaN         NaN  2012.000000      692.000000
# max           NaN         NaN  2016.000000     3087.000000
#
#        Delays.Late Aircraft  Delays.National Aviation System  Delays.Security  \
# count           4408.000000                      4408.000000      4408.000000
# mean             789.078947                       954.580309         5.575544
# std              561.798420                       921.907801         6.007046
# ...

# %% [markdown]
# # correlation

# %%
air.corr()
# Out:
#                                           Unnamed: 2  Unnamed: 3      Year  \
# Unnamed: 2                                       NaN         NaN       NaN
# Unnamed: 3                                       NaN         NaN       NaN
# Year                                             NaN         NaN  1.000000
# Delays.Carrier                                   NaN         NaN -0.067204
# Delays.Late Aircraft                             NaN         NaN  0.000373
# Delays.National Aviation System                  NaN         NaN -0.195279
# Delays.Security                                  NaN         NaN -0.315334
# Delays.Weather                                   NaN         NaN -0.191346
# Carriers.Total                                   NaN         NaN -0.483083
# Flights.Cancelled                                NaN         NaN -0.046951
# Flights.Delayed                                  NaN         NaN -0.127542
# ...

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(air.corr(), annot=True,linewidth=.5,center=0,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Month details

# %%
air['Month'].value_counts()
# Out:
# January      377
# September    377
# November     377
# July         377
# June         377
# August       377
# October      377
# December     377
# April        348
# May          348
# March        348
# Febuary      348
# Name: Month, dtype: int64

# %% [markdown]
# # query to extract details of January

# %%
air_jan=air.loc[(air['Month']=='January')]
air_jan
# Out:
#      Airport.Code                                       Airport.Name  \
# 203           ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 204           BOS                    Boston, MA: Logan International
# 205           BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 206           CLT     Charlotte, NC: Charlotte Douglas International
# 207           DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#       Unnamed: 2  Unnamed: 3    Month  Year  Delays.Carrier  \
# 203          NaN         NaN  January  2004            1302
# ...

# %% [markdown]
# # Mean values in january

# %%
air_jan.mean()
# Out:
# Unnamed: 2                                            NaN
# Unnamed: 3                                            NaN
# Year                                          2010.000000
# Delays.Carrier                                 585.034483
# Delays.Late Aircraft                           767.387268
# Delays.National Aviation System                958.355438
# Delays.Security                                  6.007958
# Delays.Weather                                  93.840849
# Carriers.Total                                  12.074271
# Flights.Cancelled                              340.729443
# Flights.Delayed                               2410.580902
# Flights.Diverted                                22.281167
# Flights.On Time                               8800.824934
# Flights.Total                                11574.416446
# Minutes Delayed.Carrier                      35825.201592
# Minutes Delayed.Late Aircraft                48042.673740
# ...

# %% [markdown]
# # query to extract details of December

# %%
air_dec=air.loc[(air['Month']=='December')]
air_dec
# Out:
#      Airport.Code                                       Airport.Name  \
# 174           ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 175           BOS                    Boston, MA: Logan International
# 176           BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 177           CLT     Charlotte, NC: Charlotte Douglas International
# 178           DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4374          SAN             San Diego, CA: San Diego International
# 4375          SEA          Seattle, WA: Seattle/Tacoma International
# 4376          SFO     San Francisco, CA: San Francisco International
# 4377          SLC   Salt Lake City, UT: Salt Lake City International
# 4378          TPA                     Tampa, FL: Tampa International
#
#       Unnamed: 2  Unnamed: 3     Month  Year  Delays.Carrier  \
# 174          NaN         NaN  December  2003            1303
# ...

# %% [markdown]
# # Mean values in December

# %%
air_dec.mean()
# Out:
# Unnamed: 2                                            NaN
# Unnamed: 3                                            NaN
# Year                                          2009.000000
# Delays.Carrier                                 716.021220
# Delays.Late Aircraft                           987.132626
# Delays.National Aviation System               1110.867374
# Delays.Security                                  8.848806
# Delays.Weather                                  99.766578
# Carriers.Total                                  12.270557
# Flights.Cancelled                              286.541114
# Flights.Delayed                               2922.623342
# Flights.Diverted                                24.798408
# Flights.On Time                               8548.981432
# Flights.Total                                11782.944297
# Minutes Delayed.Carrier                      42523.437666
# Minutes Delayed.Late Aircraft                62753.076923
# ...

# %% [markdown]
# # Year details

# %%
air['Year'].value_counts()
# Out:
# 2004    348
# 2008    348
# 2012    348
# 2005    348
# 2009    348
# 2013    348
# 2006    348
# 2010    348
# 2014    348
# 2007    348
# 2011    348
# 2015    348
# 2003    203
# 2016     29
# Name: Year, dtype: int64

# %% [markdown]
# # query to extract the details in the year 2016

# %%
air_2016=air.loc[(air['Year']==2016)]
air_2016
# Out:
#      Airport.Code                                       Airport.Name  \
# 4379          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 4380          BOS                    Boston, MA: Logan International
# 4381          BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 4382          CLT     Charlotte, NC: Charlotte Douglas International
# 4383          DCA  Washington, DC: Ronald Reagan Washington National
# 4384          DEN                   Denver, CO: Denver International
# 4385          DFW  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...
# 4386          DTW            Detroit, MI: Detroit Metro Wayne County
# 4387          EWR           Newark, NJ: Newark Liberty International
# 4388          FLL  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...
# 4389          IAD    Washington, DC: Washington Dulles International
# 4390          IAH  Houston, TX: George Bush Intercontinental/Houston
# 4391          JFK        New York, NY: John F. Kennedy International
# ...

# %% [markdown]
# # Flights details in 2016

# %%
f_2016=air_2016[['Flights.Cancelled','Flights.Diverted','Flights.On Time','Flights.Total']]
f_2016
# Out:
#       Flights.Cancelled  Flights.Diverted  Flights.On Time  Flights.Total
# 4379                429                17            25424          29854
# 4380                274                 9             7216           9100
# 4381                619                11             5711           7174
# 4382                615                 8             7292           9224
# 4383                600                10             4817           6455
# 4384                231                 7            15291          17527
# 4385                247                15            14158          16572
# 4386                186                26             7864           9463
# 4387                836                20             6343           8536
# 4388                235                22             5429           7665
# 4389                242                 3             2003           2533
# 4390                173                40             9967          11642
# ...

# %% [markdown]
# # Mean values

# %%
f_2016.mean()
# Out:
# Flights.Cancelled      303.310345
# Flights.Diverted        15.482759
# Flights.On Time       8322.862069
# Flights.Total        10297.724138
# dtype: float64

# %% [markdown]
# # query to extract the details in the year 2003

# %%
air_2003=air.loc[(air['Year']==2003)]
air_2003
# Out:
#     Airport.Code                                       Airport.Name  \
# 0            ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1            BOS                    Boston, MA: Logan International
# 2            BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3            CLT     Charlotte, NC: Charlotte Douglas International
# 4            DCA  Washington, DC: Ronald Reagan Washington National
# ..           ...                                                ...
# 198          SAN             San Diego, CA: San Diego International
# 199          SEA          Seattle, WA: Seattle/Tacoma International
# 200          SFO     San Francisco, CA: San Francisco International
# 201          SLC   Salt Lake City, UT: Salt Lake City International
# 202          TPA                     Tampa, FL: Tampa International
#
#      Unnamed: 2  Unnamed: 3     Month  Year  Delays.Carrier  \
# 0           NaN         NaN      June  2003            1009
# ...

# %% [markdown]
# # Grouping National Aviation System Delays based on year

# %%
nas_delay=air.groupby(['Year']).agg({'Delays.National Aviation System':'sum'})
nas_delay
# Out:
#       Delays.National Aviation System
# Year
# 2003                           203062
# 2004                           410657
# 2005                           402032
# 2006                           417756
# 2007                           444187
# 2008                           408170
# 2009                           339737
# 2010                           277309
# 2011                           266026
# 2012                           225322
# 2013                           282015
# 2014                           274536
# 2015                           240811
# 2016                            16170

# %% [markdown]
# # Grouping  Late Aircraft Delays based on year

# %%
late_delay=air.groupby(['Year']).agg({'Delays.Late Aircraft':'sum'})
late_delay
# Out:
#       Delays.Late Aircraft
# Year
# 2003                104421
# 2004                242625
# 2005                269560
# 2006                323979
# 2007                369520
# 2008                306661
# 2009                247225
# 2010                253551
# 2011                255142
# 2012                241010
# 2013                304028
# 2014                296854
# 2015                247441
# 2016                 16243

# %% [markdown]
# # Grouping Security Delays based on year

# %%
sec_delay=air.groupby(['Year']).agg({'Delays.Security':'sum'})
sec_delay
# Out:
#       Delays.Security
# Year
# 2003             1468
# 2004             3084
# 2005             2212
# 2006             3555
# 2007             2941
# 2008             1860
# 2009             1343
# 2010             1770
# 2011             1373
# 2012             1240
# 2013             1441
# 2014              987
# 2015             1206
# 2016               97

# %% [markdown]
# # Security Delays based on year

# %%
plt.figure(figsize=(15,3))
sns.lineplot(x='Year',y='Delays.Security',data=sec_delay,marker="s",color="green")
plt.xticks(rotation=80)

plt.title('Security Delays vs year')
plt.show()

# %% [markdown]
# # Grouping  Delays due to Weather based on year

# %%
weather_delay=air.groupby(['Year']).agg({'Delays.Weather':'sum'})
weather_delay
# Out:
#       Delays.Weather
# Year
# 2003           15514
# 2004           35484
# 2005           33110
# 2006           35307
# 2007           39531
# 2008           31237
# 2009           25065
# 2010           21440
# 2011           19402
# 2012           18592
# 2013           22323
# 2014           22881
# 2015           23394
# 2016            1500

# %%
d1
# Out:
#            Delays.Carrier  Delays.Late Aircraft  \
# Month
# April              181262                251618
# August             238472                328113
# December           269940                372149
# Febuary            185021                258725
# January            220558                289305
# July               265161                381057
# June               256751                372132
# March              209490                292867
# May                187871                264997
# November           172366                222966
# October            182416                242683
# September          163672                201648
#
#            Delays.National Aviation System  Delays.Security  Delays.Weather
# Month
# April                               312505             1592           20177
# August                              358986             3258           34528
# December                            418797             3336           37612
# ...

# %% [markdown]
# # delay details of January

# %%
plt.figure(figsize=(12,8)) ##5=width, 10=length
ax=plt.axes()
ax.set_facecolor('yellowgreen')
plt.bar(["Delays.Carrier","Delays.Late Aircraft","Delays.National Aviation System","Delays.Security","Delays.Weather"],[220558,289305,361300,2265,35378],label="delays details",color='r',width=0.5)

plt.legend()
plt.xlabel('delays')
plt.ylabel('count')
plt.title('Delays in january')
plt.show()

# %% [markdown]
# ### In january more delays occured due to National Aviation System.least delays are occured due to security and weather.

# %% [markdown]
# # delay details of  June,September,December

# %%
import numpy as np
plt.style.use('seaborn-darkgrid')
x=["Delays.Carrier","Delays.Late Aircraft","Delays.National Aviation System","Delays.Security","Delays.Weather"]
y=np.array([256751,372132,413259,2324,41251])
y1=np.array([163672,201648,282856,1371,19104])
y2=np.array([269940,372149,418797,3336,37612])

plt.figure(figsize=(10,7))
plt.barh(x,y,label="June",color='r')
plt.barh(x,y1,label="September",left=y,color='b')
plt.barh(x,y2,label="december",left=y+y1,color='g')

plt.xlabel('Delay')
plt.ylabel('count')
plt.title('Delay details')
plt.legend()
plt.show()

# %% [markdown]
# ### From this we can understand that most of the delays occured due to the national aviation system. security delays occured very rarely.

# %%
f1
# Out:
#            Flights.Cancelled  Flights.Delayed  Flights.Diverted  \
# Month
# April                  55172           767134              8599
# August                 74052           963240             14262
# December              108026          1101829              9349
# Febuary               125630           801497              6945
# January               128455           908789              8400
# July                   79194          1084630             16660
# June                   78791          1085637             16833
# March                  77751           874674              8171
# May                    53908           817071             11524
# November               44491           730990              6886
# October                56295           783858              7281
# September              59599           668669              7989
#
#            Flights.On Time  Flights.Total
# Month
# April              3297188        4128093
# ...

# %% [markdown]
# # Strip plot

# %%
plt.figure(figsize=(12,12))
sns.set_style("darkgrid")
sns.stripplot(x="Year",y="Flights.Cancelled",jitter=.50,data=air)
plt.show()

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(f1)
plt.show()

# %%
f2
# Out:
#       Flights.Cancelled  Flights.Delayed  Flights.Diverted  Flights.On Time  \
# Year
# 2003              34598           411570              4791          1922147
# 2004              77940           880677              8731          3377387
# 2005              83188           925578              8978          3355778
# 2006              78475          1024612             11058          3323807
# 2007             102665          1129439             11510          3294874
# 2008              87650           965136             11245          3243618
# 2009              58341           787472              9780          3183307
# 2010              75018           732445              9783          3233526
# 2011              77467           715560              9364          3120904
# 2012              53494           658326              7941          3235628
# 2013              62054           805063              9454          3231826
# ...

# %%
sns.pairplot(air[air.Year.isin([2005,2010,2015])],
            hue='Year',
            vars=['Flights.Cancelled','Flights.Delayed','Flights.Diverted'],
            palette='inferno_r')
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ### The Airlines data describes details of various flights on time and delays data in different airports across the world.

# %% [markdown]
# ### The flight delays are mainly due to the following reasons:

# %% [markdown]
# ### Air Carrier: The cause of the cancellation or delay was due to circumstances within the airline's control (e.g. maintenance or crew problems, aircraft cleaning, baggage loading, fueling, etc.).

# %% [markdown]
# ### Extreme Weather: Significant meteorological conditions (actual or forecasted) that, in the judgment of the carrier, delays or prevents the operation of a flight such as tornado, blizzard or hurricane.

# %% [markdown]
# ### National Aviation System (NAS): Delays and cancellations attributable to the national aviation system that refer to a broad set of conditions, such as non-extreme weather conditions, airport operations, heavy traffic volume, and air traffic control.

# %% [markdown]
# ### Late-arriving aircraft: A previous flight with same aircraft arrived late, causing the present flight to depart late.

# %% [markdown]
# ### Security: Delays or cancellations caused by evacuation of a terminal or concourse, re-boarding of aircraft because of security breach, inoperative screening equipment and/or long lines in excess of 29 minutes at screening areas.

# %% [markdown]
# ### From the above analysis we can clearly realize that most of the delays are occured due to the National Aviation System (NAS).Then due to Late-arriving aircraft.Least delays are occured due to Security and weather.

# %% [markdown]
# # THANKYOU
